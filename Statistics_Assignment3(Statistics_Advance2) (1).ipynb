# %%
#Theory question

# %%
#1. What is Hypothesis Testing in Statistics?

#ans.>> it is a cliam or statement or an assumption about a population parameter that can be tested using statistical method ,
#       which is used to make decisions or inferences about population parameters based on sample data

# %%
#2. What is the Null Hypothesis and How Does It Differ from the Alternative Hypothesis?

#ans.>> 1. null hypothesis :- the initail or default assumption, assumption that there is no effect or no difference
#       2. Alternative hypothesis :- opposite of null hypothesis , The statement you want to test ,that there is an effect or difference.

# %%
#3. What is the Significance Level in Hypothesis Testing, and Why is It Important?

#ans.>>Significance level (alpha): The probability threshold below which you reject the null hypothesis. Common values are 0.05
#      It controls the risk of a Type I error (false positive).

# %%
#4. What Does a P-Value Represent in Hypothesis Testing?

#ans.>> P-value is the probability value, calculated from a statistical test (corresponding to zscore of sample)
#       P-value in hypothesis testing is used to decied wheather to reject a null hypothesis or not#5. How Do You Interpret the P-Value in Hypothesis Testing?

# %%
#6. What are Type 1 and Type 2 Errors in Hypothesis Testing?

#ans.>> 1. Type 1 error :- is the rejection of the null hypothesis when it is actully true
#       2. Type 2 error :- is the failure to reject the null hypothesis that is actully false

# %%
#5. How Do You Interpret the P-Value in Hypothesis Testing?

#ans.>> this is how we interpret the p-value in hypothesis testing :-
#        1.P-value ≤ alpha: Reject the null hypothesis
#        2.P-value > alpha: Do not reject the null hypothesis

# %%
#7. What is the Difference Between a One-Tailed and a Two-Tailed Test?

#ans.>> these are the difference betweeen one-tail and two-tail test :-
#          1. one-tail test :- in this type of test there is rejection region at one side of distribution ( where is mu = '>','<')
#          2. two-tail test :- in this type of test there is rejection region at both side of distribution( where is mu = '=','≠')

# %%
#8. What is the Z-Test, and When is It Used?

#ans.>> Z-test is used when the population standard deviation is given (known), and the sample size is greater than equals to 30 (n >= 30).
#      it was Commonly used for comparing sample mean to a known population mean.

# %%
#9. How Do You Calculate the Z-Score, and What Does It Represent?

#ans.>> z score is calculated , which is measure how many standard deviations the sample mean is from the population mean.
#       calculation of z score = (mean of sample - population mean)/(sd of population/square root of sample size)

# %%
#10. What is the T-Distribution, and When Should It Be Used?

#ans.>> it will be used when he sample size is less then 30 (n < 30) and the population standard deviation is not given (unknown)
#       1. for normal distribution tail are thin
#       2. as the degree of freedom decrease tail become thicker
#       3. the t-distribution is depends on degree of freedom

# %%
#11. What is the Difference Between a Z-Test and a T-Test?

#ans.>> 1.Z-test is used when the population standard deviation is given (known), and the sample size is greater than equals to 30 (n >= 30).
#       2.t-test is  used when the sample size is less then 30 (n < 30) and the population standard deviation is not given (unknown)

# %%
#12. What is the T-Test, and How is It Used in Hypothesis Testing?

#ans.>> A T-test compares means to determine if they are significantly different.
#      1. t-test is  used when the sample size is less then 30 (n < 30) and the population standard deviation is not given (unknown)

# %%
#13. Relationship Between Z-Test and T-Test

#ans.>> these are the relationship between :-
#       Both z-test and t-test compare means, but
#       Z-test is for large samples or known population variance,
#       while T-test is for smaller samples or unknown population variance

# %%
#14. What is a Confidence Interval, and How is It Used?

#ans.>> A range of values likely to contain the population parameter with a certain level of confidence
#      If the interval does not include the null hypothesis value, the result is statistically significant

# %%
#15. What is the Margin of Error, and How Does It Affect the Confidence Interval?

#ans.>> margin of error is nothing , it is a alpha value in hypothesis testing
#         Margin of error (ME) = critical valu × standard error
#        Larger margin >> wider confidence interval >> less precise estimate

# %%
#16. How is Bayes' Theorem Used in Statistics, and What is Its Significance?

#ans.>> the probability of a hypothesis based on new evidence.
#       Used in decision-making, machine learning, and diagnostics
#        P(A/B) = [P(A) . P(B/A)]/P(B)#17. What is the Chi-Square Distribution, and When is It Used?

# %%
#17. What is the Chi-Square Distribution, and When is It Used?

#ans.>> the chi-square distribution is a probablity distribution that describe the distribution of a sum of chi-square of a sum of square of k random varibale
#     here , degree of freedom (K) = n-1
#     it was used in :
#      1. to test goodness of fit test >> to compare observed & expected categorical data
#      2. test of independence >> to determine the relationship between two categorical varibale

# %%
#18. What is the Chi-Square Goodness-of-Fit Test, and How is It Applied?

#ans.>> chi-square is to test goodness of fit test >> to compare observed & expected categorical data
#            chi-square = [∑(observed - expected)**2]/expected

# %%
#19. What is the F-Distribution, and When is It Used in Hypothesis Testing?

#ans.>> ANOVA is a statistical method used to compare the mean of 2 or more groups
#         1. generally ANOVA is used for more than 2 groups
#         2. reason : for two groups you can also used t-test
#      Used to compare two variances or in ANOVA.

# %%
#20. What is an ANOVA Test, and What Are Its Assumptions?

#ans.>>ANOVA is a statistical method used to compare the mean of 2 or more groups
#      these are its assumption :-
#         1.the population fromwhich sample are drawn should be normally distributed
#         2.the sample should be independent of each other/random
#         3.absence of outlier
#         4.homogenity of variance :- homogenity means that the variance mong the groups should be approximately equal

# %%
#21. What Are the Different Types of ANOVA Tests?

#ans.>> these are the types of ANOVA :-
#        1. one way ANOVA
#        2.repeated measure ANOVA
#        3. FActorical ANOVA

# %%
#22. What is the F-Test, and How Does It Relate to Hypothesis Testing?

#ans.>> An F-test compares two variances or is used in ANOVA to compare group means.
#       F = variance between groups / variance within groups

# %% [markdown]
# practical question

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint , bernoulli ,binom , poisson , uniform , norm , stats , skew, kurtosis
import warnings
warnings.filterwarnings("ignore")

# %%
#1.Write a Python program to generate a random variable and display its value
import numpy as np
R = np.random.rand()
print("random variable 'R' :",R)
# Out:
# random variable 'R' : 0.10082250335478082

# %%
#2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

#we rolled a dice
from scipy.stats import randint
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the dice roll
low = 1
high = 7  # upper bound in randint is exclusive

d = np.arange(low, high)
prob = randint(low, high).pmf(d)  # create a distribution object and then call pmf

plt.hist(d, weights=prob, color="skyblue", edgecolor="black")
plt.xlabel("dice")
plt.ylabel("prob")
plt.title("Discrete Uniform Distribution (PMF)")
plt.grid()
plt.show()

# %%
#3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
from scipy.stats import bernoulli
def bernoulli_pdf(p,x):
    return bernoulli.pmf(x,p)

print("bernoulli PFD :",bernoulli_pdf(0.8,1.5))
# Out:
# bernoulli PFD : 0.0

# %%
#4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
from scipy.stats import binom

n=10
p=0.5
bino = binom.rvs(n,p,size=1000)
plt.hist(bino , color = "red",edgecolor = "black")
plt.title("binomial distribution histogram")
plt.xlabel("no. of successes")
plt.ylabel("frequency")
plt.show()

# %%
#5.Create a Poisson distribution and visualize it using Python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint , bernoulli ,binom , poisson , uniform , norm , stats , skew, kurtosis
import warnings
warnings.filterwarnings("ignore")
freq = np.arange(0,15)
pmf = poisson.pmf(freq,mu=7.5)

plt.stem(freq,pmf)
plt.title("Poisson distribution PMF")
plt.xlabel("freq")
plt.ylabel("PMF")
plt.show()

# %%
#6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Range set karo
low, high = 1, 10

# x ko define karo
x = np.arange(low, high + 1)

# CDF calculate karo
cdf = randint.cdf(x, low, high)

# Plot CDF
plt.step(x, cdf, where='post')
plt.xlabel('x')
plt.ylabel('CDF')
plt.title('CDF of Discrete Uniform Distribution')
plt.grid(True)
plt.show()

# %%
#7.Generate a continuous uniform distribution using NumPy and visualize it
a = 10
b = 30
data = uniform.rvs(loc=a, scale=b - a, size=1000)

plt.hist(data, bins=30, density=True, color='skyblue', edgecolor='black')
plt.title('Continuous Uniform Distribution (10 to 20)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#8.Simulate data from a normal distribution and plot its histogram
mean = 0
std_dev = 1
data = np.random.normal(mean, std_dev, 500)

plt.hist(data,bins = 50 ,color='turquoise', edgecolor='teal')
plt.title('Histogram of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#9.Write a Python function to calculate Z-scores from a dataset and plot them

data = np.random.normal(50, 30, 100)
z_scores = (data - np.mean(data)) / np.std(data)

plt.hist(z_scores, bins=30, color='peachpuff', edgecolor='chocolate')
plt.title('Z-Scores of Dataset')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %%
#10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

means = [np.mean(np.random.exponential(scale=2.0, size=30)) for _ in range(1000)]

plt.hist(means, bins=30, color='teal', edgecolor='black', density=True)
plt.title('CLT: Sample Means')
plt.xlabel('Mean')
plt.ylabel('Density')
plt.show()

# %%
#11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

means = []
for _ in range(1000):
    sample = np.random.normal(loc=50, scale=10, size=30)
    means.append(np.mean(sample))

plt.hist(means, bins=30, color='skyblue', edgecolor='black')
plt.title('CLT - Distribution of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#12>Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)
plt.plot(x, y, color='red')
plt.title('Standard Normal Distribution PDF')
plt.xlabel('Z')
plt.ylabel('Probability Density')
plt.grid()
plt.show()

# %%
#13.Generate random variables and calculate their corresponding probabilities using the binomial distribution

n, p = 10, 0.5
x = np.arange(0, n+1)
probabilities = binom.pmf(x, n, p)
print("Binomial Probabilities:", probabilities)
# Out:
# Binomial Probabilities: [0.00097656 0.00976563 0.04394531 0.1171875  0.20507812 0.24609375
#  0.20507812 0.1171875  0.04394531 0.00976563 0.00097656]

# %%
#14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
def calculate_z_score(x, mean, std):
    z = (x - mean) / std
    print(f"Z-score of {x} is {z}")
    return z

z = calculate_z_score(75, 70, 5)
print("P(Z < z):", norm.cdf(z))
# Out:
# Z-score of 75 is 1.0
# P(Z < z): 0.8413447460685429

# %%
#15.Implement hypothesis testing using Z-statistics for a sample dataset

def z_test(sample_mean, population_mean, std_dev, n, alpha=0.05):
    z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
    p_value = 2 * (1 - norm.cdf(abs(z)))
    print("Z-score:", z)
    print("P-value:", p_value)
    if p_value < alpha:
        print("Reject Null Hypothesis")
    else:
        print("Fail to Reject Null Hypothesis")

z_test(102, 100, 10, 30)
# Out:
# Z-score: 1.0954451150103321
# P-value: 0.27332167829229803
# Fail to Reject Null Hypothesis

# %%
#16.Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
from scipy.stats import t
from scipy.stats import sem

# Generate data
data = np.random.normal(100, 15, 50)

# Mean and standard error
mean = np.mean(data)
se = sem(data)

# Degrees of freedom
df = len(data) - 1

# Confidence level
confidence = 0.95
alpha = 1 - confidence

# t-critical value
t_crit = t.ppf(1 - alpha/2, df)

# Margin of error
margin = t_crit * se

# %%
#17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
from scipy.stats import norm, sem

# Generate data
data = np.random.normal(120, 12, 100)

# Mean and standard error
mean = np.mean(data)
se = sem(data)

# Confidence level
confidence = 0.95
z_score = norm.ppf((1 + confidence) / 2)  # 1.96 for 95%

# Margin of error
margin = z_score * se

# Confidence interval
ci_lower = mean - margin
ci_upper = mean + margin

print(f"Mean = {mean:.2f}, 95% CI = ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Mean = 118.85, 95% CI = (116.76, 120.93)

# %%
#18.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
x = np.linspace(60, 100, 1000)
pdf = norm.pdf(x, 80, 10)
plt.plot(x, pdf, label='PDF')
plt.title('Normal Distribution PDF')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.legend()
plt.show()

# %%
x = np.arange(0, 15)
cdf = poisson.cdf(x, mu=5)
plt.step(x, cdf, where='post', label='CDF')
plt.title('Poisson Distribution CDF (λ=5)')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()

# %%
#20.Simulate a random variable using a continuous uniform distribution and calculate its expected value
a = 5
b = 15
sample = np.random.uniform(a, b, 1000)
expected = (a + b) / 2
print("Expected Value:", expected)
# Out:
# Expected Value: 10.0

# %%
#21.Write a Python program to compare the standard deviations of two datasets and visualize the difference
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(50, 20, 1000)

print("Std Dev 1:", np.std(data1))
print("Std Dev 2:", np.std(data2))

plt.hist(data1, bins=30, alpha=0.5, label='SD=10')
plt.hist(data2, bins=30, alpha=0.5, label='SD=20')
plt.title('Comparison of Standard Deviations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Std Dev 1: 9.738663547786052
# Std Dev 2: 19.24139194481719

# %%
22.#Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

data = np.random.normal(30, 5, 100)
data_range = np.max(data) - np.min(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print("Range:", data_range)
print("Interquartile Range (IQR):", iqr)
# Out:
# Range: 24.67551066555896
# Interquartile Range (IQR): 5.93878223750659

# %%
#23.Implement Z-score normalization on a dataset and visualize its transformation

data = np.random.normal(80, 13, 1000)
z_scores = (data - np.mean(data)) / np.std(data)

plt.hist(z_scores, bins=20, color='cornflowerblue', edgecolor='navy')
plt.title('Z-score Normalized Data')
plt.grid()
plt.show()

# %%
#24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution

data = np.random.normal(0, 1, 1000)
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: -0.03383659667083421
# Kurtosis: 0.008456059821622564

# %% [markdown]
# practical question 2

# %%
#1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results
def one_sample_z_test(sample, pop_mean, pop_std):
    n = len(sample)
    sample_mean = np.mean(sample)
    z = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - norm.cdf(abs(z)))
    print(f"Z-score: {z:.2f}, P-value: {p_value:.4f}")
    return z, p_value

sample = np.random.normal(100, 15, 50)
one_sample_z_test(sample, pop_mean=100, pop_std=15)
# Out:
# Z-score: 0.67, P-value: 0.5021
# (np.float64(0.6712552304364918), np.float64(0.5020579496676334))

# %%
#2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

sample = np.random.normal(105, 10, 30)
z, p = one_sample_z_test(sample, pop_mean=100, pop_std=10)
print("Hypothesis Test Result:", "Reject H0" if p < 0.05 else "Fail to Reject H0")
# Out:
# Z-score: 2.95, P-value: 0.0032
# Hypothesis Test Result: Reject H0

# %%
#3.Implement a one-sample Z-test using Python to compare the sample mean with the population mean

import numpy as np
import scipy.stats as stats

# Sample data and population parameters
sample_data = [45, 50, 52, 48, 49]
population_mean = 50
population_std = 5

# Z-test calculation
sample_mean = np.mean(sample_data)
z = (sample_mean - population_mean) / (population_std / np.sqrt(len(sample_data)))

# p-value for two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(z)))

print(f"Z-statistic: {z}")
print(f"p-value: {p_value}")

# Interpretation
print("Reject H0" if p_value < 0.05 else "Fail to reject H0")
# Out:
# Z-statistic: -0.5366563145999508
# p-value: 0.5915050369949157
# Fail to reject H0

# %%
#4.Perform a two-tailed Z-test using Python and visualize the decision region on a plot
def visualize_z_test(z, alpha=0.05):
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x)

    z_critical = norm.ppf(1 - alpha / 2)

    plt.plot(x, y, label='Standard Normal Distribution')
    plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3, label='Rejection Region')
    plt.axvline(z, color='blue', linestyle='--', label=f'Z-score = {z:.2f}')
    plt.title("Two-Tailed Z-test Decision Region")
    plt.legend()
    plt.grid(True)
    plt.show()

visualize_z_test(z)

# %%
#5.Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing
def visualize_type_errors(mu0=0, mu1=1, sigma=1, n=30, alpha=0.05):
    se = sigma / np.sqrt(n)
    x = np.linspace(-4, 4, 1000)

    z_crit = norm.ppf(1 - alpha / 2)
    x_cutoff = mu0 + z_crit * se

    plt.plot(x, norm.pdf(x, mu0, se), label='H0', color='blue')
    plt.plot(x, norm.pdf(x, mu1, se), label='H1', color='green')

    plt.fill_between(x, norm.pdf(x, mu0, se), where=(x > x_cutoff), color='red', alpha=0.3, label='Type I Error (α)')
    plt.fill_between(x, norm.pdf(x, mu1, se), where=(x < x_cutoff), color='orange', alpha=0.3, label='Type II Error (β)')

    plt.legend()
    plt.grid(True)
    plt.title("Type I and Type II Errors")
    plt.show()

visualize_type_errors()

# %%
#6.Write a Python program to perform an independent T-test and interpret the results


from scipy.stats import ttest_ind

group1 = np.random.normal(40, 8, 30)
group2 = np.random.normal(35, 5, 30)
t_stat, p_val = ttest_ind(group1, group2)
print("Independent T-test: t =", t_stat, "p =", p_val)
# Out:
# Independent T-test: t = 1.0018737201141383 p = 0.32056621564225396

# %%
#7.Perform a paired sample T-test using Python and visualize the comparison results
from scipy.stats import ttest_rel

before = np.random.normal(42, 8, 30)
after = before + np.random.normal(2, 3, 30)

t_stat, p_val = ttest_rel(before, after)
print("Paired T-test: t =", t_stat, "p =", p_val)

plt.plot(before, label='Before')
plt.plot(after, label='After')
plt.title("Paired Samples Comparison")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Paired T-test: t = -6.604619903154885 p = 3.077235406618726e-07

# %%
#8.Simulate data and perform both Z-test and T-test, then compare the results using Python

from scipy.stats import ttest_1samp

sample = np.random.normal(102, 10, 25)
pop_mean = 100

print("Z-test:")
z, p_z = one_sample_z_test(sample, pop_mean, pop_std=10)

print("T-test:")
t_stat, p_t = ttest_1samp(sample, pop_mean)
print(f"t = {t_stat:.2f}, p = {p_t:.4f}")
# Out:
# Z-test:
# Z-score: 0.70, P-value: 0.4866
# T-test:
# t = 0.59, p = 0.5626

# %%
#9.Write a Python function to calculate the confidence interval for a sample mean and explain its significance

from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    sem = stats.sem(data)
    n = len(data)
    margin = t.ppf((1 + confidence) / 2., n-1) * sem
    ci = (mean - margin, mean + margin)
    print(f"Mean = {mean:.2f}, 95% CI = {ci}")
    return ci

data = np.random.normal(70, 10, 50)
confidence_interval(data)
# Out:
# Mean = 69.75, 95% CI = (np.float64(67.05045301343841), np.float64(72.45119138515705))
# (np.float64(67.05045301343841), np.float64(72.45119138515705))

# %%
#10.Write a Python program to calculate the margin of error for a given confidence level using sample data
import numpy as np
from scipy.stats import t, sem

data = np.random.normal(100, 15, 50)
confidence = 0.95

mean = np.mean(data)
standard_error = sem(data)
t_value = t.ppf((1 + confidence) / 2, df=len(data)-1)

margin_error = t_value * standard_error

# Print both margin of error and confidence interval
print("Margin of Error:", margin_error)
print(f"95% Confidence Interval: ({mean - margin_error:.2f}, {mean + margin_error:.2f})")
# Out:
# Margin of Error: 4.243328967917052
# 95% Confidence Interval: (95.83, 104.32)

# %%
#11.Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

P_disease = 0.01
P_no_disease = 1 - P_disease

P_positive_given_disease = 0.99
P_positive_given_no_disease = 0.05

P_positive = (P_positive_given_disease * P_disease) + (P_positive_given_no_disease * P_no_disease)# Total probability of testing positive

P_disease_given_positive = (P_positive_given_disease * P_disease) / P_positive # Bayes' Theorem

print("Probability of having the disease given a positive test:", round(P_disease_given_positive, 4))
# Out:
# Probability of having the disease given a positive test: 0.1667

# %%
#12.Perform a Chi-square test for independence between two categorical variables in Python
import pandas as pd
from scipy.stats import chi2_contingency

data = [[20, 15],
        [30, 35]]

table = pd.DataFrame(data, columns=['Group A', 'Group B'], index=['Yes', 'No'])
chi2, p, dof, expected = chi2_contingency(table) # Perform Chi-square test for independence

print("Chi-square value:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)


if p < 0.05:  # Interpretation
    print("Variables are dependent (reject H0)")
else:
    print("Variables are independent (fail to reject H0)")
# Out:
# Chi-square value: 0.7032967032967032
# p-value: 0.4016781664697727
# Degrees of freedom: 1
# Expected frequencies:
#  [[17.5 17.5]
#  [32.5 32.5]]
# Variables are independent (fail to reject H0)

# %%
#13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data
from scipy.stats import chi2_contingency

observed = [[10, 20], [30, 40]]
chi2, p, _, _ = chi2_contingency(observed)

print(f"p-value: {p}")
print("Dependent" if p < 0.05 else "Independent")
# Out:
# p-value: 0.5040358664525046
# Independent

# %%
#14.Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
from scipy.stats import chisquare

observed = [18, 22, 20, 25, 15] # Observed frequencies
expected = [20, 20, 20, 20, 20] # Expected frequencies (e.g., equal distribution)
chi2_stat, p_val = chisquare(f_obs=observed, f_exp=expected) # Perform Chi-square goodness-of-fit test

print("Chi-square statistic:", chi2_stat)
print("p-value:", p_val)

# Interpretation
if p_val < 0.05:
    print("Observed data does NOT fit the expected distribution (reject H0)")
else:
    print("Observed data fits the expected distribution (fail to reject H0)")
# Out:
# Chi-square statistic: 2.9
# p-value: 0.5746972058298043
# Observed data fits the expected distribution (fail to reject H0)
